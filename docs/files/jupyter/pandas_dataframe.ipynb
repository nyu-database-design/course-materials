# %% [markdown]
# # DataFrames in pandas
# A set of examples that exhibit some of the core features of the [DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html) data type in the `pandas` module.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic concept
# A DataFrame is a two-dimensional tabular data struture.  It is easily visualized like a spreadsheet, with rows and columns.

# %%
# create a DataFrame from a dictionary containing labeled pandas Series
df = pd.DataFrame({
    'name': pd.Series( ['Foo', 'Bar', 'Baz'] ),
    'email': pd.Series( ['fo1258@foo.edu', 'br9876@foo.edu', 'bz2292@foo.edu'] ),
    'midterm exam': pd.Series( [99, 64, 87] ),
    'final exam': pd.Series( [94, 72, 81] )
})
df
# Out:
#   name           email  midterm exam  final exam
# 0  Foo  fo1258@foo.edu            99          94
# 1  Bar  br9876@foo.edu            64          72
# 2  Baz  bz2292@foo.edu            87          81

# %% [markdown]
# ### Columns as Series
# Each column is a named `pandas` Series.

# %%
df['midterm exam']
# Out:
# 0    99
# 1    64
# 2    87
# Name: midterm exam, dtype: int64

# %%
# prove that a column of a DataFrame is a Series
type( df['midterm exam'] )
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Rows
# Each row is also considered a `pandas` Series.

# %%
# get a row by its index
df.loc[1]
# Out:
# name                       Bar
# email           br9876@foo.edu
# midterm exam                64
# final exam                  72
# Name: 1, dtype: object

# %%
# prove that a row of a DataFrame is a Series
type( df.loc[1] )
# Out:
# pandas.core.series.Series

# %%
# get a row by its integer index
df.iloc[2]
# Out:
# name                       Baz
# email           bz2292@foo.edu
# midterm exam                87
# final exam                  81
# Name: 2, dtype: object

# %% [markdown]
# ## Filtering rows

# %%
# match a criterion
df[ df['name'] == 'Bar' ]
# Out:
#   name           email  midterm exam  final exam
# 1  Bar  br9876@foo.edu            64          72

# %%
# match multiple criteria using & or | logic operators
df[ (df['name'] != 'Bar') & (df['midterm exam'] > 50) ]
# Out:
#   name           email  midterm exam  final exam
# 0  Foo  fo1258@foo.edu            99          94
# 2  Baz  bz2292@foo.edu            87          81

# %% [markdown]
# ## Filtering columns

# %% [markdown]
# Extracting a **single column** is straightforward with square bracket syntax.

# %%
# fetch the 'name' column - this returns a Series
df['name']
# Out:
# 0    Foo
# 1    Bar
# 2    Baz
# Name: name, dtype: object

# %% [markdown]
# The easiest way to extract **multiple columns** from a dataframe is by supplying a list of column names.

# %%
# fetch the 'name' and 'final exam' columns - this returns a DataFrame
df[ ['name', 'final exam'] ]
# Out:
#   name  final exam
# 0  Foo          94
# 1  Bar          72
# 2  Baz          81

# %% [markdown]
# ## Filtering rows and columns

# %% [markdown]
# It is possible to use two sets of brackets to perform both row and column filters in one expression.

# %%
# find one row by its index, and fetch one column from the results - this returns a single value
df.loc[2]['final exam']
# Out:
# 81

# %%
# filter rows by criteria, and fetch one column from the results - this returns a Series
df[ df['name'] != 'Baz']['midterm exam']
# Out:
# 0    99
# 1    64
# Name: midterm exam, dtype: int64

# %%
# filter rows, and fetch multiple columns from the results - this returns a DataFrame
df[ df['name'] != 'Baz'][ ['name', 'midterm exam'] ]
# Out:
#   name  midterm exam
# 0  Foo            99
# 1  Bar            64

# %% [markdown]
# ## Importing data from files
# Pandas can import from a variety of common data file formats, including CSV, JSON, fixed-width column text, and more.

# %%
# open data about NYC jobs from https://data.cityofnewyork.us/City-Government/NYC-Jobs/kpav-sd4t
df = pd.read_csv('./NYC_Jobs.csv')

# %%
# show a few randomly-sampled rows
df.sample(3)
# Out:
#       Job ID                      Agency Posting Type  # Of Positions  \
# 1021  424227  FINANCIAL INFO SVCS AGENCY     External               1
# 812   458502  DEPT OF PARKS & RECREATION     Internal              50
# 474   246734   ADMIN FOR CHILDREN'S SVCS     External               1
#
#                          Business Title      Civil Service Title  \
# 1021          Web Application Developer      SENIOR IT ARCHITECT
# 812                  City Seasonal Aide       CITY SEASONAL AIDE
# 474   Compliance Review Unit Supervisor  ASSOCIATE STAFF ANALYST
#
#      Title Classification Title Code No Level  \
# 1021    Non-Competitive-5         95711    00
# 812     Non-Competitive-5         91406    00
# 474         Competitive-1         12627    00
#
#                             Job Category  ...  \
# 1021       Technology, Data & Innovation  ...
# 812    Building Operations & Maintenance  ...
# 474   Finance, Accounting, & Procurement  ...
#
#                                  Additional Information  \
# 1021                                               P293
# 812   THIS JOB VACANCY NOTICE IS ONLY FOR CITY SEASO...
# 474   Section 424-A of the New York Social Services ...
#
#                                                To Apply  \
# 1021  External applicants please visit https://a127-...
# 812   Please submit a cover letter and resume.  Park...
# 474                      Click on the Apply Now button.
#
#                         Hours/Shift  Work Location 1 Recruitment Contact  \
# 1021  Monday - Friday, 9am  to 5pm.              NaN                 NaN
# 812                             NaN           Queens                 NaN
# 474                             NaN              NaN                 NaN
#
#                                   Residency Requirement Posting Date  \
# 1021  New York City Residency is not required for th...   11/27/2019
# 812   Residency in New York City, Nassau, Orange, Ro...   02/19/2021
# 474   New York City residency is generally required ...   08/05/2016
#
#      Post Until Posting Updated Process Date
# 1021        NaN      11/27/2019   04/13/2021
# 812         NaN      04/06/2021   04/13/2021
# 474         NaN      08/08/2016   04/13/2021
#
# [3 rows x 30 columns]

# %%
# look for good-paying jobs ( > $200,000) available for external candidates
df[ (df['Posting Type'] == 'External') & (df['Salary Frequency'] == 'Annual') & (df['Salary Range To'] >= 200000) ]
# Out:
#       Job ID                         Agency Posting Type  # Of Positions  \
# 111   441015   DEPARTMENT OF TRANSPORTATION     External               2
# 176   432041      ADMIN FOR CHILDREN'S SVCS     External               1
# 195   457777  OFFICE OF MANAGEMENT & BUDGET     External               1
# 263   445754          NYC HOUSING AUTHORITY     External               1
# 332   434222   NYC EMPLOYEES RETIREMENT SYS     External               1
# 369   459608   NYC EMPLOYEES RETIREMENT SYS     External               1
# 401   459041   NYC EMPLOYEES RETIREMENT SYS     External               1
# 438   458110      OFFICE OF THE COMPTROLLER     External               1
# 644   453677   NYC EMPLOYEES RETIREMENT SYS     External               1
# 734   441706    TAXI & LIMOUSINE COMMISSION     External               1
# 735   440527   NYC EMPLOYEES RETIREMENT SYS     External               1
# 759   373748   NYC EMPLOYEES RETIREMENT SYS     External               1
# 773   457622   DEPT OF INFO TECH & TELECOMM     External               1
# 967   456308    TAXI & LIMOUSINE COMMISSION     External               1
# 993   458280       DEPARTMENT OF SANITATION     External               1
# 1052  459311  OFFICE OF MANAGEMENT & BUDGET     External               1
#
#                                          Business Title  \
# 111                              Deputy General Counsel
# 176    Deputy Commissioner, Child and Family Well-Being
# 195                 Assistant Director  Citywide Grants
# 263       Vice President for Operation Support Services
# 332                            COMPUTER SYSTEMS MANAGER
# 369   ADMINISTRATIVE RETIREMENT BENEFITS SPECIALIST,...
# 401                        ADMINISTRATIVE STAFF ANALYST
# 438                                  Chief Risk Officer
# 644                   ADMINISTRATIVE MANAGEMENT AUDITOR
# 734   General Counsel/Deputy Commissioner for Legal ...
# 735                   ADMINISTRATIVE MANAGEMENT AUDITOR
# 759                   ADMINISTRATIVE MANAGEMENT AUDITOR
# 773                      Deputy CISO - Urban Technology
# 967                       Deputy Commissioner of Policy
# 993   Deputy Director of Commercial Waste, Contracts...
# 1052      Assistant Director  Administration of Justice
#
#                  Civil Service Title      Title Classification Title Code No  \
# 111         EXECUTIVE AGENCY COUNSEL         Non-Competitive-5         95005
# 176   DEPUTY DIRECTOR OF ADMINISTRAT         Non-Competitive-5         52485
# 195   BUDGET ANALYST (OMB)-MANAGERIA  Pending Classification-2         0608A
# 263   ADMINISTRATIVE HOUSING SUPERIN             Competitive-1         10019
# 332         COMPUTER SYSTEMS MANAGER             Competitive-1         10050
# 369   ADMINISTRATIVE RETIREMENT BENE             Competitive-1         82986
# 401   ADMINISTRATIVE STAFF ANALYST (             Competitive-1         10026
# 438   DIRECTOR OF  INVESTMENTS (COMP         Non-Competitive-5         95612
# 644   ADMINISTRATIVE MANAGEMENT AUDI             Competitive-1         10010
# 734         EXECUTIVE AGENCY COUNSEL         Non-Competitive-5         95005
# 735   ADMINISTRATIVE MANAGEMENT AUDI             Competitive-1         10010
# 759   ADMINISTRATIVE MANAGEMENT AUDI             Competitive-1         10010
# 773        TELECOMMUNICATION MANAGER             Competitive-1         82984
# 967         EXECUTIVE AGENCY COUNSEL         Non-Competitive-5         95005
# 993   ADMINISTRATIVE BUSINESS PROMOT             Competitive-1         10009
# 1052  BUDGET ANALYST (OMB)-MANAGERIA  Pending Classification-2         0608A
#
#      Level                                       Job Category  ...  \
# 111     M5                                      Legal Affairs  ...
# 176     M7                                    Social Services  ...
# 195     M4  Finance, Accounting, & Procurement Legal Affai...  ...
# 263     M5                  Building Operations & Maintenance  ...
# 332     M7                      Technology, Data & Innovation  ...
# 369     M5                   Administration & Human Resources  ...
# 401     M7          Public Safety, Inspections, & Enforcement  ...
# 438     MY                 Finance, Accounting, & Procurement  ...
# 644     M5                   Administration & Human Resources  ...
# 734     M6                                      Legal Affairs  ...
# 735     M5                   Administration & Human Resources  ...
# 759     M7  Administration & Human Resources Finance, Acco...  ...
# 773     M5                      Technology, Data & Innovation  ...
# 967     M7                        Policy, Research & Analysis  ...
# 993     M4                 Finance, Accounting, & Procurement  ...
# 1052    M4  Finance, Accounting, & Procurement Policy, Res...  ...
#
#                                  Additional Information  \
# 111                                                 NaN
# 176   Section 424-A of the New York Social Services ...
# 195   REQUIREMENTS:  Assistant Director ($141,766+):...
# 263   1.\tNYCHA employees applying for promotional, ...
# 332                                                 NaN
# 369                                                 NaN
# 401                                                 NaN
# 438   The selected candidate will be subject to the ...
# 644                                                 NaN
# 734                                                 NaN
# 735                                                 NaN
# 759                                                 NaN
# 773                                                 NaN
# 967                                                 NaN
# 993                                                 NaN
# 1052  REQUIREMENTS:  Assistant Director ($141,766): ...
#
#                                                To Apply  \
# 111   All resumes are to be submitted electronically...
# 176                           Click on Apply Now button
# 195   For City employees, please go to Employee Self...
# 263                         Click the Apply Now button.
# 332   TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...
# 369   TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...
# 401   TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...
# 438   Please visit our website at https://comptrolle...
# 644   TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...
# 734   Click, APPLY NOW Current city employees must a...
# 735   TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...
# 759   TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...
# 773   Special Note: Taking and passing civil service...
# 967   Click, APPLY NOW Current city employees must a...
# 993   To apply, please submit resume and cover lette...
# 1052  For City employees, please go to Employee Self...
#
#                                             Hours/Shift  \
# 111                                                 NaN
# 176                                                 NaN
# 195                                                 NaN
# 263                                                 NaN
# 332                                                 NaN
# 369                                                 NaN
# 401                                                 NaN
# 438                                                 NaN
# 644                                                 NaN
# 734                                                 NaN
# 735                                                 NaN
# 759                                                 NaN
# 773   Day - Due to the necessary technical managemen...
# 967                                                 NaN
# 993                                   35 hours per week
# 1052                                                NaN
#
#                      Work Location 1 Recruitment Contact  \
# 111                55 Water St Ny Ny                 NaN
# 176                              NaN                 NaN
# 195             255 Greenwich Street                 NaN
# 263                              NaN                 NaN
# 332                              NaN                 NaN
# 369                              NaN                 NaN
# 401                              NaN                 NaN
# 438                              NaN                 NaN
# 644                              NaN                 NaN
# 734        33 Beaver St, New York Ny                 NaN
# 735                              NaN                 NaN
# 759                              NaN                 NaN
# 773                     New York, NY                 NaN
# 967        33 Beaver St, New York Ny                 NaN
# 993   125 Worth Street, New York, NY                 NaN
# 1052            255 Greenwich Street                 NaN
#
#                                   Residency Requirement Posting Date  \
# 111   New York City residency is generally required ...   08/21/2020
# 176   New York City residency is generally required ...   02/04/2020
# 195   New York City residency is generally required ...   02/02/2021
# 263                NYCHA has no residency requirements.   09/23/2020
# 332   New York City Residency is not required for th...   02/18/2020
# 369   New York City residency is generally required ...   03/15/2021
# 401   New York City residency is generally required ...   03/03/2021
# 438   New York City residency is generally required ...   02/08/2021
# 644   New York City residency is generally required ...   11/17/2020
# 734   New York City residency is generally required ...   07/13/2020
# 735   New York City residency is generally required ...   06/24/2020
# 759   New York City residency is generally required ...   11/07/2018
# 773   New York City residency is generally required ...   02/03/2021
# 967   New York City residency is generally required ...   01/06/2021
# 993   New York City Residency is required within 90 ...   03/15/2021
# 1052  New York City residency is generally required ...   03/10/2021
#
#        Post Until Posting Updated Process Date
# 111           NaN      08/21/2020   04/13/2021
# 176           NaN      02/04/2020   04/13/2021
# 195           NaN      02/02/2021   04/13/2021
# 263           NaN      02/16/2021   04/13/2021
# 332           NaN      02/18/2020   04/13/2021
# 369           NaN      03/15/2021   04/13/2021
# 401   30-APR-2021      03/03/2021   04/13/2021
# 438           NaN      02/08/2021   04/13/2021
# 644           NaN      11/17/2020   04/13/2021
# 734           NaN      07/13/2020   04/13/2021
# 735           NaN      07/07/2020   04/13/2021
# 759           NaN      11/07/2018   04/13/2021
# 773           NaN      02/11/2021   04/13/2021
# 967           NaN      01/06/2021   04/13/2021
# 993           NaN      03/16/2021   04/13/2021
# 1052          NaN      03/10/2021   04/13/2021
#
# [16 rows x 30 columns]
